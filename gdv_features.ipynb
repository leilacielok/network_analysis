# %%
# !pip install orbit-count
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 kB 10.4 MB/s eta 0:00:00
# ...

# %%
import networkx as nx
import orbit_count
import numpy as np
import pandas as pd

# %%
G_und = nx.read_edgelist("G_und.edgelist", nodetype=int)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_395/43829957.py in <cell line: 0>()
# ----> 1 G_und = nx.read_edgelist("G_und.edgelist", nodetype=int)
#
# /usr/local/lib/python3.12/dist-packages/networkx/utils/decorators.py in func(_argmap__wrapper, *args, **kwargs)
#     782
#     783         def func(*args, __wrapper=None, **kwargs):
# --> 784             return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#     785
#     786         # standard function-wrapping stuff
#
# /usr/local/lib/python3.12/dist-packages/networkx/utils/decorators.py in argmap_read_edgelist_1(path, comments, delimiter, create_using, nodetype, data, edgetype, encoding, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# ...
